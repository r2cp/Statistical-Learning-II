# %%
# %matplotlib inline
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()  # for plot styling

from sklearn import metrics
from sklearn.cluster import KMeans
from sklearn.datasets import fetch_openml

from sklearn.decomposition import PCA

# %%
def mostrar_digito(digito):
    digito = digito.reshape(8, 8)
    plt.imshow(digito, cmap = matplotlib.cm.binary, interpolation="nearest")
    plt.axis("off")
    plt.show()

# %% [markdown]
# # Cargando los Datos (MNIST)

# %%
from sklearn.datasets import load_digits
digits = load_digits()

x = digits.data
x.shape
# Out:
# (1797, 64)

# %%
digits.target
# Out:
# array([0, 1, 2, ..., 8, 9, 8])

# %%
def plot_digits(data):
    fig, axes = plt.subplots(4, 10, figsize=(10, 4),
                             subplot_kw = {'xticks':[], 'yticks':[]},
                             gridspec_kw = dict(hspace=0.1, wspace=0.1))
    for i, ax in enumerate(axes.flat):
        ax.imshow(data[i].reshape(8, 8),
                  cmap='binary', interpolation='nearest',
                  clim=(0, 16))
plot_digits(x)

# %%
pca = PCA(n_components = 2)
pca.fit(x)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=2, random_state=None,
#     svd_solver='auto', tol=0.0, whiten=False)

# %%
print(pca.explained_variance_ratio_)
# Out:
# [0.14890594 0.13618771]

# %%
import sklearn
sklearn.__version__
# Out:
# '0.21.2'

# %%
#### PCA a 2 dimensiones ######
X2D = pca.transform(x) #new features matrix
X2D
# Out:
# array([[ -1.25946647,  21.27488346],
#        [  7.95761125, -20.7686991 ],
#        [  6.99192297,  -9.9559863 ],
#        ...,
#        [ 10.80128363,  -6.96025223],
#        [ -4.87210004,  12.42395364],
#        [ -0.34438958,   6.36554932]])

# %%
print(x.shape)
print(X2D.shape)
# Out:
# (1797, 64)
# (1797, 2)

# %%
plt.scatter(X2D[:, 0], X2D[:, 1])
plt.xlabel('component 1')
plt.ylabel('component 2')
# Out:
# Text(0, 0.5, 'component 2')

# %%
plt.scatter(X2D[:, 0], X2D[:, 1],
            c=digits.target, edgecolor='none', alpha=0.4,
            cmap=plt.cm.get_cmap('Accent', 10))
plt.colorbar()

# %% [markdown]
# ## K-means Clustering con Sklearn
#
# [Documentacion oficial](http://scikit-learn.org/stable/modules/generated/sklearn.cluster.KMeans.html)

# %%
## K-means
kmeans = KMeans(n_clusters=10)
kmeans.fit(X2D)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=10, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
kmeans.labels_
# Out:
# array([0, 8, 1, ..., 1, 7, 5], dtype=int32)

# %%
centers = kmeans.cluster_centers_ ## clustes de kmeans
centers
# Out:
# array([[  1.65038117,  21.53566669],
#        [  4.04927358,  -8.25979371],
#        [ 22.31062008,  -1.18640663],
#        [-22.09868626,   5.39840943],
#        [ 16.66412938,  12.46497911],
#        [ -3.61857484,   0.59632688],
#        [-13.80704269,  -7.15834258],
#        [-13.07576356,  11.3179874 ],
#        [  9.20925048, -19.46631352],
#        [ -3.68801075, -17.08762803]])

# %%
kmeans.cluster_centers_.shape
# Out:
# (10, 2)

# %%
kmeans.cluster_centers_
# Out:
# array([[  1.65038117,  21.53566669],
#        [  4.04927358,  -8.25979371],
#        [ 22.31062008,  -1.18640663],
#        [-22.09868626,   5.39840943],
#        [ 16.66412938,  12.46497911],
#        [ -3.61857484,   0.59632688],
#        [-13.80704269,  -7.15834258],
#        [-13.07576356,  11.3179874 ],
#        [  9.20925048, -19.46631352],
#        [ -3.68801075, -17.08762803]])

# %%
plt.scatter(X2D[:, 0], X2D[:, 1],
            c=digits.target, edgecolor='none', alpha=0.5,
            cmap=plt.cm.get_cmap('Accent', 10))
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5);
